# %% [markdown]
# #  Coursera Capstone Project - The Battle of Neighbourhoods

# %% [markdown]
# ## Week 2

# %% [markdown]
# ## Introduction <a name="introduction"></a>

# %% [markdown]
# New York City is the largest and most populous city in the United States, 2018 it's population was 8,398,748. It consists of five boroughs – Brooklyn, Queens, Manhattan, The Bronx, and Staten Island, each of which is a separate county of the State of New York. Each borough has its own demographic, cultural, linguistic and financial specificities.
#
# But you don't have to be Italian to like pizza. I mean a good pizza, made according to an old Italian recipe.
# Then a delicious espresso. Yes, a well crafted espresso tastes great. And ice cream.
#
#
# In this project, I'm going to **explore the location** of good, high rated **Italian restaurants** in New York City and **find a place where such a restaurant is missing**. We will look for highly populated areas with not many other Italian restaurants in vicinity.

# %% [markdown]
# #### Goal and stakeholders

# %% [markdown]
# The goal of this project is to explore the following questions:
# **1. What is best location in New York City for italian cuisine?**
# **2. Which areas lack italian resturants?  **
#
# **Stakeholders** interested in the problem:
# Investors planning to open an Italian restaurant

# %% [markdown]
# ## Data <a name="data"></a>

# %% [markdown]
# We will use the following data:

# %% [markdown]
# #### 1. New York City data to explore various neighborhoods of New York City.
# This dataset covers boroughs along with their neighborhoods, latitude and longitude
#
# Dataset source:
# https://geo.nyu.edu/catalog/nyu_2451_34572

# %% [markdown]
# ####  2. GeoSpace data
# The geo space data allow to get the New York Borough boundaries.
# It let us visualize choropleth map.
#
# Source:
# https://data.cityofnewyork.us/City-Government/Borough-Boundaries/tqmj-j8zm

# %% [markdown]
# #### 3. Location of the Italian restaurants in New York City
#
# a) By using the Fousquare API we will get all the venues in each neighborhood.
# b) Then we can filter out only Italian restaurants.
# c) We can also find ratings, tips and like count for each restaurant.
# That allows us to sort and visualize the data.
#
# Source:
# **Fousquare API**
#  <br><br><br>

# %% [markdown]
# ## Methodology <a name="methodology"></a>
#
# In this project we want to detect areas of New York that have a low density of Italian restaurant bit a high population density.
#
# First, We have collected the data:
# * location of Boroughs and Neighborhoods
# * location of Italian restaurant in each Neighborhood (within 1500 m from their center)
# * the population of the Boroughs
#
# In the next step we analysed the '**restaurant density**' across the Boroughs of New York.
# In the final step we focused on the most populated areas and filtered out the Neighborhoods with the least number of Italian restaurants. <br><br>
# These are the most promising areas which should be attractive to investors.

# %% [markdown]
# ### Load dependencies

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import numpy as np
import requests
import json
import os

import geocoder
from geopy.geocoders import Nominatim 

import folium 
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
# %matplotlib inline

# %% [markdown]
# #### Data sources and variables

# %%
newYorkUrl='https://cocl.us/new_york_dataset'

cityName = 'New York City, NY'

# %% [markdown]
# #### Define Helper Functions

# %%
# get geo location of address
def geo_location(address):
    geolocator = Nominatim(user_agent="ny_explorer")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    return latitude,longitude

def get_new_york_data(url):
    resp=requests.get(url).json()
    features=resp['features']
    
    column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 
    new_york_data = pd.DataFrame(columns=column_names)
    
    for data in features:
        borough = data['properties']['borough'] 
        neighborhood_name = data['properties']['name']
        
        neighborhood_latlon = data['geometry']['coordinates']
        neighborhood_lat = neighborhood_latlon[1]
        neighborhood_lon = neighborhood_latlon[0]
    
        new_york_data = new_york_data.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)
    
    return new_york_data

def get_location_of_NYC(name):
    geolocator = Nominatim(user_agent="ny_explorer")
    location = geolocator.geocode(name)
    latitude = location.latitude
    longitude = location.longitude
    print('The geograpical coordinates of {} are {}, {}.'.format(name, latitude, longitude))
    return latitude, longitude
    

def create_map():
    latitude, longitude = get_location_of_NYC(cityName)
    neighborhoods  = nyc_data
    map_newyork = folium.Map(location=[latitude, longitude], zoom_start=10)
    # add markers to map
    for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
        label = '{}, {}'.format(neighborhood, borough)
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker(
            [lat, lng],
            radius=5,
            popup=label,
            color='blue',
            fill=True,
            fill_color='#3186cc',
            fill_opacity=0.7,
            parse_html=False).add_to(map_newyork)  
    return map_newyork
        
# get top 400 venues within the neighborhoods
def get_venues(lat,lng, CLIENT_ID, CLIENT_SECRET):
    radius=1500
    LIMIT=400
    VERSION = '20180605' 
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
    
    # get all the data
    results = requests.get(url).json()
    venue_data=results["response"]['groups'][0]['items']
    venue_details=[]
    for row in venue_data:
        try:
            venue_id=row['venue']['id']
            venue_name=row['venue']['name']
            venue_category=row['venue']['categories'][0]['name']
            venue_lat = row['venue']['location']['lat']
            venue_lng =  row['venue']['location']['lng']
            venue_details.append([venue_id,venue_name,venue_category, venue_lat, venue_lng])
        except KeyError:
            pass
        
    column_names=['ID','Name','Category', 'Latitude', 'Longitude']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %% [markdown]
# ## Distribution of Italian Restaurants in New York City

# %%
latitude, longitude = get_location_of_NYC(cityName)
# Out:
# The geograpical coordinates of New York City, NY are 40.7127281, -74.0060152.

# %% [markdown]
# #### Dataframe
# Let's create a Dataframe with Boroughs, Neighborhoods and their coordinates
# <br>

# %%
nyc_data = get_new_york_data(newYorkUrl)
print('New York City has {} boroughs and {} nyc_data.'.format(len(nyc_data['Borough'].unique()),
                                                                   nyc_data.shape[0]))
# Out:
# New York City has 5 boroughs and 306 nyc_data.

# %%
nyc_data.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %% [markdown]
# #### Visualize the neigborhoods
# Dokladnie rzecz biorac mapa nie przedstawia granic osieli? tylko ich centra.

# %%
map_newyork = folium.Map(location=[latitude, longitude], zoom_start=10)
neighborhoods = nyc_data
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], 
                                           
        neighborhoods['Longitude'], neighborhoods['Borough'], 
                                           neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label,parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=1,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_newyork)  
    
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CLIENT_ID = 'hidden_ID' 
CLIENT_SECRET = 'hidden_SECRET' 
VERSION = '20180605'

# %% [markdown]
# ##   Foursquare

# %% [markdown]
# ### Get the top 400 venues within a radius of 1500 m from the center of every neighborhood
# Let's use Foursquare API to get info on Italian restaurants in each neighborhood.
# We're interested in venues in proper Italian restaurants, we won't care about places like coffe shops or bakeries etc.

# %%
# italian restaurants for each neighborhood
column_names=['Borough', 'Neighborhood', 'ID','Name']
italian_rest=pd.DataFrame(columns=column_names)
count=1
for row in nyc_data.values.tolist():
    Borough, Neighborhood, Latitude, Longitude=row
    venues = get_venues(Latitude,Longitude, CLIENT_ID, CLIENT_SECRET)
    italian_resturants=venues[venues['Category']=='Italian Restaurant']   
    print('(',count,'/',len(nyc_data),')','Italian Resturants in '+Neighborhood+', '+Borough+':'+str(len(italian_resturants)))
    for resturant_detail in italian_resturants.values.tolist():
        id, name , category, latitude, longitude =resturant_detail
        italian_rest = italian_rest.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name,
                                                'Latitude' : latitude,
                                                'Longitude' : longitude
                                               }, ignore_index=True)
    count+=1
# Out:
# ( 1 / 306 ) Italian Resturants in Wakefield, Bronx:2
# ( 2 / 306 ) Italian Resturants in Co-op City, Bronx:1
# ( 3 / 306 ) Italian Resturants in Eastchester, Bronx:0
# ( 4 / 306 ) Italian Resturants in Fieldston, Bronx:2
# ( 5 / 306 ) Italian Resturants in Riverdale, Bronx:0
# ( 6 / 306 ) Italian Resturants in Kingsbridge, Bronx:0
# ( 7 / 306 ) Italian Resturants in Marble Hill, Manhattan:0
# ( 8 / 306 ) Italian Resturants in Woodlawn, Bronx:4
# ( 9 / 306 ) Italian Resturants in Norwood, Bronx:0
# ( 10 / 306 ) Italian Resturants in Williamsbridge, Bronx:0
# ( 11 / 306 ) Italian Resturants in Baychester, Bronx:2
# ( 12 / 306 ) Italian Resturants in Pelham Parkway, Bronx:7
# ( 13 / 306 ) Italian Resturants in City Island, Bronx:3
# ( 14 / 306 ) Italian Resturants in Bedford Park, Bronx:1
# ( 15 / 306 ) Italian Resturants in University Heights, Bronx:0
# ( 16 / 306 ) Italian Resturants in Morris Heights, Bronx:0
# ( 17 / 306 ) Italian Resturants in Fordham, Bronx:15
# ( 18 / 306 ) Italian Resturants in East Tremont, Bronx:14
# ( 19 / 306 ) Italian Resturants in West Farms, Bronx:0
# ( 20 / 306 ) Italian Resturants in High  Bridge, Bronx:2
# ( 21 / 306 ) Italian Resturants in Melrose, Bronx:3
# ( 22 / 306 ) Italian Resturants in Mott Haven, Bronx:2
# ( 23 / 306 ) Italian Resturants in Port Morris, Bronx:2
# ( 24 / 306 ) Italian Resturants in Longwood, Bronx:1
# ( 25 / 306 ) Italian Resturants in Hunts Point, Bronx:0
# ( 26 / 306 ) Italian Resturants in Morrisania, Bronx:2
# ( 27 / 306 ) Italian Resturants in Soundview, Bronx:0
# ( 28 / 306 ) Italian Resturants in Clason Point, Bronx:0
# ( 29 / 306 ) Italian Resturants in Throgs Neck, Bronx:7
# ( 30 / 306 ) Italian Resturants in Country Club, Bronx:3
# ( 31 / 306 ) Italian Resturants in Parkchester, Bronx:3
# ( 32 / 306 ) Italian Resturants in Westchester Square, Bronx:2
# ( 33 / 306 ) Italian Resturants in Van Nest, Bronx:4
# ( 34 / 306 ) Italian Resturants in Morris Park, Bronx:5
# ( 35 / 306 ) Italian Resturants in Belmont, Bronx:15
# ( 36 / 306 ) Italian Resturants in Spuyten Duyvil, Bronx:1
# ( 37 / 306 ) Italian Resturants in North Riverdale, Bronx:2
# ( 38 / 306 ) Italian Resturants in Pelham Bay, Bronx:4
# ( 39 / 306 ) Italian Resturants in Schuylerville, Bronx:4
# ( 40 / 306 ) Italian Resturants in Edgewater Park, Bronx:7
# ( 41 / 306 ) Italian Resturants in Castle Hill, Bronx:0
# ( 42 / 306 ) Italian Resturants in Olinville, Bronx:0
# ( 43 / 306 ) Italian Resturants in Pelham Gardens, Bronx:4
# ( 44 / 306 ) Italian Resturants in Concourse, Bronx:1
# ( 45 / 306 ) Italian Resturants in Unionport, Bronx:0
# ( 46 / 306 ) Italian Resturants in Edenwald, Bronx:0
# ( 47 / 306 ) Italian Resturants in Bay Ridge, Brooklyn:5
# ( 48 / 306 ) Italian Resturants in Bensonhurst, Brooklyn:8
# ( 49 / 306 ) Italian Resturants in Sunset Park, Brooklyn:1
# ( 50 / 306 ) Italian Resturants in Greenpoint, Brooklyn:3
# ( 51 / 306 ) Italian Resturants in Gravesend, Brooklyn:2
# ( 52 / 306 ) Italian Resturants in Brighton Beach, Brooklyn:1
# ( 53 / 306 ) Italian Resturants in Sheepshead Bay, Brooklyn:2
# ( 54 / 306 ) Italian Resturants in Manhattan Terrace, Brooklyn:2
# ( 55 / 306 ) Italian Resturants in Flatbush, Brooklyn:1
# ( 56 / 306 ) Italian Resturants in Crown Heights, Brooklyn:2
# ( 57 / 306 ) Italian Resturants in East Flatbush, Brooklyn:0
# ( 58 / 306 ) Italian Resturants in Kensington, Brooklyn:1
# ( 59 / 306 ) Italian Resturants in Windsor Terrace, Brooklyn:6
# ( 60 / 306 ) Italian Resturants in Prospect Heights, Brooklyn:2
# ( 61 / 306 ) Italian Resturants in Brownsville, Brooklyn:0
# ( 62 / 306 ) Italian Resturants in Williamsburg, Brooklyn:0
# ( 63 / 306 ) Italian Resturants in Bushwick, Brooklyn:2
# ( 64 / 306 ) Italian Resturants in Bedford Stuyvesant, Brooklyn:0
# ( 65 / 306 ) Italian Resturants in Brooklyn Heights, Brooklyn:6
# ( 66 / 306 ) Italian Resturants in Cobble Hill, Brooklyn:6
# ( 67 / 306 ) Italian Resturants in Carroll Gardens, Brooklyn:3
# ( 68 / 306 ) Italian Resturants in Red Hook, Brooklyn:4
# ( 69 / 306 ) Italian Resturants in Gowanus, Brooklyn:4
# ( 70 / 306 ) Italian Resturants in Fort Greene, Brooklyn:5
# ( 71 / 306 ) Italian Resturants in Park Slope, Brooklyn:2
# ( 72 / 306 ) Italian Resturants in Cypress Hills, Brooklyn:0
# ( 73 / 306 ) Italian Resturants in East New York, Brooklyn:0
# ( 74 / 306 ) Italian Resturants in Starrett City, Brooklyn:1
# ( 75 / 306 ) Italian Resturants in Canarsie, Brooklyn:0
# ( 76 / 306 ) Italian Resturants in Flatlands, Brooklyn:4
# ( 77 / 306 ) Italian Resturants in Mill Island, Brooklyn:0
# ( 78 / 306 ) Italian Resturants in Manhattan Beach, Brooklyn:1
# ( 79 / 306 ) Italian Resturants in Coney Island, Brooklyn:1
# ( 80 / 306 ) Italian Resturants in Bath Beach, Brooklyn:6
# ( 81 / 306 ) Italian Resturants in Borough Park, Brooklyn:3
# ( 82 / 306 ) Italian Resturants in Dyker Heights, Brooklyn:6
# ( 83 / 306 ) Italian Resturants in Gerritsen Beach, Brooklyn:3
# ( 84 / 306 ) Italian Resturants in Marine Park, Brooklyn:6
# ( 85 / 306 ) Italian Resturants in Clinton Hill, Brooklyn:6
# ( 86 / 306 ) Italian Resturants in Sea Gate, Brooklyn:0
# ( 87 / 306 ) Italian Resturants in Downtown, Brooklyn:2
# ( 88 / 306 ) Italian Resturants in Boerum Hill, Brooklyn:1
# ( 89 / 306 ) Italian Resturants in Prospect Lefferts Gardens, Brooklyn:2
# ( 90 / 306 ) Italian Resturants in Ocean Hill, Brooklyn:0
# ( 91 / 306 ) Italian Resturants in City Line, Brooklyn:0
# ( 92 / 306 ) Italian Resturants in Bergen Beach, Brooklyn:1
# ( 93 / 306 ) Italian Resturants in Midwood, Brooklyn:1
# ( 94 / 306 ) Italian Resturants in Prospect Park South, Brooklyn:1
# ( 95 / 306 ) Italian Resturants in Georgetown, Brooklyn:4
# ( 96 / 306 ) Italian Resturants in East Williamsburg, Brooklyn:2
# ( 97 / 306 ) Italian Resturants in North Side, Brooklyn:2
# ( 98 / 306 ) Italian Resturants in South Side, Brooklyn:0
# ( 99 / 306 ) Italian Resturants in Ocean Parkway, Brooklyn:4
# ( 100 / 306 ) Italian Resturants in Fort Hamilton, Brooklyn:5
# ( 101 / 306 ) Italian Resturants in Chinatown, Manhattan:3
# ( 102 / 306 ) Italian Resturants in Washington Heights, Manhattan:1
# ( 103 / 306 ) Italian Resturants in Inwood, Manhattan:0
# ( 104 / 306 ) Italian Resturants in Hamilton Heights, Manhattan:3
# ( 105 / 306 ) Italian Resturants in Manhattanville, Manhattan:4
# ( 106 / 306 ) Italian Resturants in Central Harlem, Manhattan:1
# ( 107 / 306 ) Italian Resturants in East Harlem, Manhattan:2
# ( 108 / 306 ) Italian Resturants in Upper East Side, Manhattan:9
# ( 109 / 306 ) Italian Resturants in Yorkville, Manhattan:8
# ( 110 / 306 ) Italian Resturants in Lenox Hill, Manhattan:7
# ( 111 / 306 ) Italian Resturants in Roosevelt Island, Manhattan:3
# ( 112 / 306 ) Italian Resturants in Upper West Side, Manhattan:4
# ( 113 / 306 ) Italian Resturants in Lincoln Square, Manhattan:2
# ( 114 / 306 ) Italian Resturants in Clinton, Manhattan:2
# ( 115 / 306 ) Italian Resturants in Midtown, Manhattan:0
# ( 116 / 306 ) Italian Resturants in Murray Hill, Manhattan:1
# ( 117 / 306 ) Italian Resturants in Chelsea, Manhattan:2
# ( 118 / 306 ) Italian Resturants in Greenwich Village, Manhattan:8
# ( 119 / 306 ) Italian Resturants in East Village, Manhattan:3
# ( 120 / 306 ) Italian Resturants in Lower East Side, Manhattan:3
# ( 121 / 306 ) Italian Resturants in Tribeca, Manhattan:4
# ( 122 / 306 ) Italian Resturants in Little Italy, Manhattan:4
# ( 123 / 306 ) Italian Resturants in Soho, Manhattan:8
# ( 124 / 306 ) Italian Resturants in West Village, Manhattan:9
# ( 125 / 306 ) Italian Resturants in Manhattan Valley, Manhattan:1
# ( 126 / 306 ) Italian Resturants in Morningside Heights, Manhattan:5
# ( 127 / 306 ) Italian Resturants in Gramercy, Manhattan:1
# ( 128 / 306 ) Italian Resturants in Battery Park City, Manhattan:0
# ( 129 / 306 ) Italian Resturants in Financial District, Manhattan:0
# ( 130 / 306 ) Italian Resturants in Astoria, Queens:3
# ( 131 / 306 ) Italian Resturants in Woodside, Queens:0
# ( 132 / 306 ) Italian Resturants in Jackson Heights, Queens:1
# ( 133 / 306 ) Italian Resturants in Elmhurst, Queens:0
# ( 134 / 306 ) Italian Resturants in Howard Beach, Queens:6
# ( 135 / 306 ) Italian Resturants in Corona, Queens:3
# ( 136 / 306 ) Italian Resturants in Forest Hills, Queens:2
# ( 137 / 306 ) Italian Resturants in Kew Gardens, Queens:0
# ( 138 / 306 ) Italian Resturants in Richmond Hill, Queens:0
# ( 139 / 306 ) Italian Resturants in Flushing, Queens:0
# ( 140 / 306 ) Italian Resturants in Long Island City, Queens:2
# ( 141 / 306 ) Italian Resturants in Sunnyside, Queens:1
# ( 142 / 306 ) Italian Resturants in East Elmhurst, Queens:1
# ( 143 / 306 ) Italian Resturants in Maspeth, Queens:2
# ( 144 / 306 ) Italian Resturants in Ridgewood, Queens:2
# ( 145 / 306 ) Italian Resturants in Glendale, Queens:0
# ( 146 / 306 ) Italian Resturants in Rego Park, Queens:2
# ( 147 / 306 ) Italian Resturants in Woodhaven, Queens:0
# ( 148 / 306 ) Italian Resturants in Ozone Park, Queens:1
# ( 149 / 306 ) Italian Resturants in South Ozone Park, Queens:1
# ( 150 / 306 ) Italian Resturants in College Point, Queens:0
# ( 151 / 306 ) Italian Resturants in Whitestone, Queens:4
# ( 152 / 306 ) Italian Resturants in Bayside, Queens:3
# ( 153 / 306 ) Italian Resturants in Auburndale, Queens:2
# ( 154 / 306 ) Italian Resturants in Little Neck, Queens:6
# ( 155 / 306 ) Italian Resturants in Douglaston, Queens:6
# ( 156 / 306 ) Italian Resturants in Glen Oaks, Queens:1
# ( 157 / 306 ) Italian Resturants in Bellerose, Queens:3
# ( 158 / 306 ) Italian Resturants in Kew Gardens Hills, Queens:0
# ( 159 / 306 ) Italian Resturants in Fresh Meadows, Queens:2
# ( 160 / 306 ) Italian Resturants in Briarwood, Queens:1
# ( 161 / 306 ) Italian Resturants in Jamaica Center, Queens:0
# ( 162 / 306 ) Italian Resturants in Oakland Gardens, Queens:2
# ( 163 / 306 ) Italian Resturants in Queens Village, Queens:1
# ( 164 / 306 ) Italian Resturants in Hollis, Queens:0
# ( 165 / 306 ) Italian Resturants in South Jamaica, Queens:0
# ( 166 / 306 ) Italian Resturants in St. Albans, Queens:0
# ( 167 / 306 ) Italian Resturants in Rochdale, Queens:0
# ( 168 / 306 ) Italian Resturants in Springfield Gardens, Queens:1
# ( 169 / 306 ) Italian Resturants in Cambria Heights, Queens:0
# ( 170 / 306 ) Italian Resturants in Rosedale, Queens:1
# ( 171 / 306 ) Italian Resturants in Far Rockaway, Queens:0
# ( 172 / 306 ) Italian Resturants in Broad Channel, Queens:0
# ( 173 / 306 ) Italian Resturants in Breezy Point, Queens:0
# ( 174 / 306 ) Italian Resturants in Steinway, Queens:4
# ( 175 / 306 ) Italian Resturants in Beechhurst, Queens:9
# ( 176 / 306 ) Italian Resturants in Bay Terrace, Queens:4
# ( 177 / 306 ) Italian Resturants in Edgemere, Queens:0
# ( 178 / 306 ) Italian Resturants in Arverne, Queens:0
# ( 179 / 306 ) Italian Resturants in Rockaway Beach, Queens:0
# ( 180 / 306 ) Italian Resturants in Neponsit, Queens:1
# ( 181 / 306 ) Italian Resturants in Murray Hill, Queens:0
# ( 182 / 306 ) Italian Resturants in Floral Park, Queens:2
# ( 183 / 306 ) Italian Resturants in Holliswood, Queens:1
# ( 184 / 306 ) Italian Resturants in Jamaica Estates, Queens:1
# ( 185 / 306 ) Italian Resturants in Queensboro Hill, Queens:0
# ( 186 / 306 ) Italian Resturants in Hillcrest, Queens:1
# ( 187 / 306 ) Italian Resturants in Ravenswood, Queens:5
# ( 188 / 306 ) Italian Resturants in Lindenwood, Queens:6
# ( 189 / 306 ) Italian Resturants in Laurelton, Queens:0
# ( 190 / 306 ) Italian Resturants in Lefrak City, Queens:3
# ( 191 / 306 ) Italian Resturants in Belle Harbor, Queens:1
# ( 192 / 306 ) Italian Resturants in Rockaway Park, Queens:1
# ( 193 / 306 ) Italian Resturants in Somerville, Queens:0
# ( 194 / 306 ) Italian Resturants in Brookville, Queens:1
# ( 195 / 306 ) Italian Resturants in Bellaire, Queens:1
# ( 196 / 306 ) Italian Resturants in North Corona, Queens:1
# ( 197 / 306 ) Italian Resturants in Forest Hills Gardens, Queens:4
# ( 198 / 306 ) Italian Resturants in St. George, Staten Island:3
# ( 199 / 306 ) Italian Resturants in New Brighton, Staten Island:3
# ( 200 / 306 ) Italian Resturants in Stapleton, Staten Island:1
# ( 201 / 306 ) Italian Resturants in Rosebank, Staten Island:3
# ( 202 / 306 ) Italian Resturants in West Brighton, Staten Island:3
# ( 203 / 306 ) Italian Resturants in Grymes Hill, Staten Island:0
# ( 204 / 306 ) Italian Resturants in Todt Hill, Staten Island:2
# ( 205 / 306 ) Italian Resturants in South Beach, Staten Island:4
# ( 206 / 306 ) Italian Resturants in Port Richmond, Staten Island:1
# ( 207 / 306 ) Italian Resturants in Mariner's Harbor, Staten Island:1
# ( 208 / 306 ) Italian Resturants in Port Ivory, Staten Island:0
# ( 209 / 306 ) Italian Resturants in Castleton Corners, Staten Island:2
# ( 210 / 306 ) Italian Resturants in New Springville, Staten Island:1
# ( 211 / 306 ) Italian Resturants in Travis, Staten Island:1
# ( 212 / 306 ) Italian Resturants in New Dorp, Staten Island:7
# ( 213 / 306 ) Italian Resturants in Oakwood, Staten Island:1
# ( 214 / 306 ) Italian Resturants in Great Kills, Staten Island:10
# ( 215 / 306 ) Italian Resturants in Eltingville, Staten Island:7
# ( 216 / 306 ) Italian Resturants in Annadale, Staten Island:3
# ( 217 / 306 ) Italian Resturants in Woodrow, Staten Island:1
# ( 218 / 306 ) Italian Resturants in Tottenville, Staten Island:5
# ( 219 / 306 ) Italian Resturants in Tompkinsville, Staten Island:3
# ( 220 / 306 ) Italian Resturants in Silver Lake, Staten Island:2
# ( 221 / 306 ) Italian Resturants in Sunnyside, Staten Island:2
# ( 222 / 306 ) Italian Resturants in Ditmas Park, Brooklyn:1
# ( 223 / 306 ) Italian Resturants in Wingate, Brooklyn:1
# ( 224 / 306 ) Italian Resturants in Rugby, Brooklyn:0
# ( 225 / 306 ) Italian Resturants in Park Hill, Staten Island:9
# ( 226 / 306 ) Italian Resturants in Westerleigh, Staten Island:3
# ( 227 / 306 ) Italian Resturants in Graniteville, Staten Island:4
# ( 228 / 306 ) Italian Resturants in Arlington, Staten Island:0
# ( 229 / 306 ) Italian Resturants in Arrochar, Staten Island:5
# ( 230 / 306 ) Italian Resturants in Grasmere, Staten Island:10
# ( 231 / 306 ) Italian Resturants in Old Town, Staten Island:11
# ( 232 / 306 ) Italian Resturants in Dongan Hills, Staten Island:11
# ( 233 / 306 ) Italian Resturants in Midland Beach, Staten Island:4
# ( 234 / 306 ) Italian Resturants in Grant City, Staten Island:7
# ( 235 / 306 ) Italian Resturants in New Dorp Beach, Staten Island:2
# ( 236 / 306 ) Italian Resturants in Bay Terrace, Staten Island:3
# ( 237 / 306 ) Italian Resturants in Huguenot, Staten Island:3
# ( 238 / 306 ) Italian Resturants in Pleasant Plains, Staten Island:1
# ( 239 / 306 ) Italian Resturants in Butler Manor, Staten Island:3
# ( 240 / 306 ) Italian Resturants in Charleston, Staten Island:2
# ( 241 / 306 ) Italian Resturants in Rossville, Staten Island:0
# ( 242 / 306 ) Italian Resturants in Arden Heights, Staten Island:1
# ( 243 / 306 ) Italian Resturants in Greenridge, Staten Island:3
# ( 244 / 306 ) Italian Resturants in Heartland Village, Staten Island:0
# ( 245 / 306 ) Italian Resturants in Chelsea, Staten Island:2
# ( 246 / 306 ) Italian Resturants in Bloomfield, Staten Island:2
# ( 247 / 306 ) Italian Resturants in Bulls Head, Staten Island:1
# ( 248 / 306 ) Italian Resturants in Carnegie Hill, Manhattan:4
# ( 249 / 306 ) Italian Resturants in Noho, Manhattan:4
# ( 250 / 306 ) Italian Resturants in Civic Center, Manhattan:2
# ( 251 / 306 ) Italian Resturants in Midtown South, Manhattan:0
# ( 252 / 306 ) Italian Resturants in Richmond Town, Staten Island:3
# ( 253 / 306 ) Italian Resturants in Shore Acres, Staten Island:5
# ( 254 / 306 ) Italian Resturants in Clifton, Staten Island:3
# ( 255 / 306 ) Italian Resturants in Concord, Staten Island:8
# ( 256 / 306 ) Italian Resturants in Emerson Hill, Staten Island:2
# ( 257 / 306 ) Italian Resturants in Randall Manor, Staten Island:2
# ( 258 / 306 ) Italian Resturants in Howland Hook, Staten Island:0
# ( 259 / 306 ) Italian Resturants in Elm Park, Staten Island:0
# ( 260 / 306 ) Italian Resturants in Remsen Village, Brooklyn:0
# ( 261 / 306 ) Italian Resturants in New Lots, Brooklyn:0
# ( 262 / 306 ) Italian Resturants in Paerdegat Basin, Brooklyn:1
# ( 263 / 306 ) Italian Resturants in Mill Basin, Brooklyn:4
# ( 264 / 306 ) Italian Resturants in Jamaica Hills, Queens:0
# ( 265 / 306 ) Italian Resturants in Utopia, Queens:1
# ( 266 / 306 ) Italian Resturants in Pomonok, Queens:0
# ( 267 / 306 ) Italian Resturants in Astoria Heights, Queens:3
# ( 268 / 306 ) Italian Resturants in Claremont Village, Bronx:2
# ( 269 / 306 ) Italian Resturants in Concourse Village, Bronx:2
# ( 270 / 306 ) Italian Resturants in Mount Eden, Bronx:0
# ( 271 / 306 ) Italian Resturants in Mount Hope, Bronx:0
# ( 272 / 306 ) Italian Resturants in Sutton Place, Manhattan:2
# ( 273 / 306 ) Italian Resturants in Hunters Point, Queens:6
# ( 274 / 306 ) Italian Resturants in Turtle Bay, Manhattan:3
# ( 275 / 306 ) Italian Resturants in Tudor City, Manhattan:1
# ( 276 / 306 ) Italian Resturants in Stuyvesant Town, Manhattan:1
# ( 277 / 306 ) Italian Resturants in Flatiron, Manhattan:1
# ( 278 / 306 ) Italian Resturants in Sunnyside Gardens, Queens:1
# ( 279 / 306 ) Italian Resturants in Blissville, Queens:1
# ( 280 / 306 ) Italian Resturants in Fulton Ferry, Brooklyn:3
# ( 281 / 306 ) Italian Resturants in Vinegar Hill, Brooklyn:2
# ( 282 / 306 ) Italian Resturants in Weeksville, Brooklyn:0
# ( 283 / 306 ) Italian Resturants in Broadway Junction, Brooklyn:0
# ( 284 / 306 ) Italian Resturants in Dumbo, Brooklyn:2
# ( 285 / 306 ) Italian Resturants in Manor Heights, Staten Island:2
# ( 286 / 306 ) Italian Resturants in Willowbrook, Staten Island:5
# ( 287 / 306 ) Italian Resturants in Sandy Ground, Staten Island:0
# ( 288 / 306 ) Italian Resturants in Egbertville, Staten Island:8
# ( 289 / 306 ) Italian Resturants in Roxbury, Queens:0
# ( 290 / 306 ) Italian Resturants in Homecrest, Brooklyn:2
# ( 291 / 306 ) Italian Resturants in Middle Village, Queens:2
# ( 292 / 306 ) Italian Resturants in Prince's Bay, Staten Island:1
# ( 293 / 306 ) Italian Resturants in Lighthouse Hill, Staten Island:3
# ( 294 / 306 ) Italian Resturants in Richmond Valley, Staten Island:7
# ( 295 / 306 ) Italian Resturants in Malba, Queens:5
# ( 296 / 306 ) Italian Resturants in Highland Park, Brooklyn:0
# ( 297 / 306 ) Italian Resturants in Madison, Brooklyn:1
# ( 298 / 306 ) Italian Resturants in Bronxdale, Bronx:4
# ( 299 / 306 ) Italian Resturants in Allerton, Bronx:2
# ( 300 / 306 ) Italian Resturants in Kingsbridge Heights, Bronx:0
# ( 301 / 306 ) Italian Resturants in Erasmus, Brooklyn:1
# ( 302 / 306 ) Italian Resturants in Hudson Yards, Manhattan:1
# ( 303 / 306 ) Italian Resturants in Hammels, Queens:0
# ( 304 / 306 ) Italian Resturants in Bayswater, Queens:0
# ( 305 / 306 ) Italian Resturants in Queensbridge, Queens:4
# ( 306 / 306 ) Italian Resturants in Fox Hills, Staten Island:3

# %% [markdown]
# #### Clean data

# %%
a=italian_rest.copy()
italian_rest.drop_duplicates(subset='ID', keep='last', inplace=True)
print("There are {} italian restaurants in 306 neighborhoods".format(italian_rest.shape[0]))
# Out:
# There are 333 italian restaurants in 306 neighborhoods

# %%
italian_rest.head(15)
# Out:
#    Borough  Neighborhood                        ID  \
# 5    Bronx      Woodlawn  511edb6de4b0d58346fd272d
# 6    Bronx      Woodlawn  4d9275a77ac3a35d6eb6c125
# 7    Bronx      Woodlawn  4d3cb3026b3d236a066a6364
# 8    Bronx      Woodlawn  5986672ef5e9d70849d99381
# 18   Bronx   City Island  4514ed4df964a520e5391fe3
# 19   Bronx   City Island  55905336498e1a9217de2a7a
# 20   Bronx   City Island  4b80a1c3f964a520488230e3
# 51   Bronx  High  Bridge  4cfe75a2feec6dcb0d1b5836
# 52   Bronx  High  Bridge  4b75e189f964a520b72b2ee3
# 59   Bronx   Port Morris  4e6acfb1ae60950955a9b02b
# 62   Bronx    Morrisania  4bb692672ea19521a6ecab2f
# 81   Bronx      Van Nest  51aa5120498ec578a5ad0ac4
# 86   Bronx   Morris Park  5197f6507dd2310725c35f1e
# 87   Bronx       Belmont  4acf80aef964a52025d420e3
# 88   Bronx       Belmont  4af0fa29f964a52060e021e3
#
#                             Name   Latitude  Longitude
# 5         Patrizia's Of Woodlawn  40.900638 -73.867724
# 6                   La Grotta II  40.907003 -73.872041
# 7                    Rivers Edge  40.901218 -73.861698
# 8                       Casa Mia  40.905293 -73.858027
# 18     Artie's Steak and Seafood  40.849542 -73.787317
# 19      Scavello's On The Island  40.841418 -73.784330
# 20          Portofino Restaurant  40.853321 -73.790693
# 51  Antika Restaurant & Pizzeria  40.838778 -73.941210
# 52                    AquaMarina  40.843199 -73.939169
# 59                       Wish 37  40.807011 -73.927563
# 62  Venice Restaurant & Pizzeria  40.812799 -73.907335
# 81                     The Pines  40.848823 -73.862153
# 86      Lorraine's Bar and Grill  40.834918 -73.854411
# 87           Tino's Delicatessen  40.855882 -73.887166
# 88           Antonio's Trattoria  40.854083 -73.886616

# %% [markdown]
# #### Visualize the location of the italian restaurants in New York

# %%
# check data
list(zip(italian_rest['Latitude'], italian_rest['Longitude'], italian_rest['Name']))[:5]
# Out:
# [(40.900638399332884, -73.86772361835486, "Patrizia's Of Woodlawn"),
#  (40.9070030100774, -73.87204139922038, 'La Grotta II'),
#  (40.90121764767051, -73.86169833552508, 'Rivers Edge'),
#  (40.905293, -73.858027, 'Casa Mia'),
#  (40.849542144998146, -73.78731730033616, "Artie's Steak and Seafood")]

# %%
map_restaurants = folium.Map(location=[latitude, longitude], zoom_start=10)
for lat, lng, name in zip(italian_rest['Latitude'], italian_rest['Longitude'], italian_rest['Name']):
    label = '{}'.format(name)
    label = folium.Popup(label,parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=1,
        popup=label,
        color='black',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.8).add_to(map_restaurants)  
    
map_restaurants
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Let's cluster and count the restaurants

# %%
from folium import plugins

map_restaurants = folium.Map(location=[latitude, longitude], zoom_start=12)

restaurants = plugins.MarkerCluster().add_to(map_restaurants)

for lat, lng, name in zip(italian_rest['Latitude'], italian_rest['Longitude'], italian_rest['Name']):
    label = '{}'.format(name)
    label = folium.Popup(label,parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=1,
        popup=label,
        color='black',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.8).add_to(restaurants)  
    
map_restaurants
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# As we can see, the italian restaurants are not really equaly distributed.

# %% [markdown]
# ## Population of New York City
# Let's look at the distribution of population density in New York.

# %%
nyc_population = pd.read_csv('New_York_City_Population_By_Boroughs.csv')
nyc_population = nyc_population[['Borough', '2010 Population']]

# %%
nyc_population.sort_values('2010 Population', ascending=False)
# Out:
#          Borough  2010 Population
# 1       Brooklyn          2504700
# 3         Queens          2230722
# 2      Manhattan          1585873
# 0          Bronx          1385108
# 4  Staten Island           468730

# %% [markdown]
# # Analysis <a name="analysis"></a>

# %% [markdown]
# ### Bring it together: Density of population and Italian restaurants

# %%
map_restaurants = folium.Map(location=[latitude, longitude], zoom_start=12)
ny_geo = 'nycboroughboundaries.geojson'

restaurants = plugins.MarkerCluster().add_to(map_restaurants)

map_restaurants.choropleth(
    geo_data=ny_geo,
    data=nyc_population,
    columns=['Borough', '2010 Population'],
    key_on='feature.properties.borough',
    fill_color='YlOrRd', 
    fill_opacity=0.7, 
    line_opacity=0.2,
    legend_name='Population'
)

for lat, lng, name in zip(italian_rest['Latitude'], italian_rest['Longitude'], italian_rest['Name']):
    label = '{}'.format(name)
    label = folium.Popup(label,parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=1,
        popup=label,
        color='black',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.8).add_to(restaurants)  

map_restaurants
# Out:
# C:\Users\KSpisak\AppData\Local\Continuum\anaconda3\lib\site-packages\folium\folium.py:432: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <br>
# Let's take a closer look at the most populated areas:

# %%
map_restaurants = folium.Map(location=[latitude, longitude], zoom_start=12)
ny_geo = 'nycboroughboundaries.geojson'

restaurants = plugins.MarkerCluster().add_to(map_restaurants)

map_restaurants.choropleth(
    geo_data=ny_geo,
    data=nyc_population,
    columns=['Borough', '2010 Population'],
    key_on='feature.properties.borough',
    fill_color='YlOrRd', 
    fill_opacity=0.7, 
    line_opacity=0.2,
    legend_name='Population'
)

for lat, lng, name in zip(italian_rest['Latitude'], italian_rest['Longitude'], italian_rest['Name']):
    label = '{}'.format(name)
    label = folium.Popup(label,parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=1,
        popup=label,
        color='black',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.8).add_to(restaurants)  

map_restaurants
# Out:
# C:\Users\KSpisak\AppData\Local\Continuum\anaconda3\lib\site-packages\folium\folium.py:432: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <br>
# The most densely populated boroughs (red) are Brooklyn and Queens.
# We can see which areas of these Boroughs have only few Italian restaurants. **They are the areas we should care about**.
# <br><br>
# Let's look for neighborhoods where there are few (or no at all) Italian restaurants.

# %%
plt.figure(figsize=(9,5), dpi = 100)
plt.title('Number of italian Resturants for each Borough in New York City')
plt.xlabel('Borough', fontsize = 15)
plt.ylabel('No.of italian Restaurants', fontsize=15)
italian_rest.groupby('Borough')['ID'].count().plot(kind='bar')
plt.show()

# %%
restPerNeighborhood = italian_rest.groupby('Neighborhood')['ID'].count().sort_values(ascending=False)

restPerNeighborhood.head()
# Out:
# Neighborhood
# Belmont            15
# West Village        9
# Bay Terrace         7
# Richmond Valley     7
# Edgewater Park      7
# Name: ID, dtype: int64

# %%
plt.figure(figsize=(9,5), dpi = 100)
plt.title('Number of Italian Resturants for each Neighborhood in New York City')
plt.xlabel('Neighborhood', fontsize = 15)
plt.ylabel('No.of Italian Restaurants', fontsize=15)
italian_rest.groupby('Neighborhood')['ID'].count().nlargest(7).plot(kind='bar')
plt.show()

# %% [markdown]
# <br>
# As you can see, most Italian restaurants are in the Belmont area.
# This is not a coincidence.
# As a result of its cultural history and wide array of Italian businesses, Belmont is known as the **"Little Italy".  **
# <br>
# <br>
# Now, Let's check out the neighborhoods of **Brooklyn** and **Queens**.

# %%
neighbQueens = italian_rest[italian_rest.Borough == 'Queens']
neighbBrooklyn = italian_rest[italian_rest.Borough == 'Brooklyn']

# %% [markdown]
# Let's look at the data

# %%
neighbBrooklyn.head()
# Out:
#       Borough Neighborhood                        ID  \
# 129  Brooklyn    Bay Ridge  4a7e205ef964a52012f11fe3
# 135  Brooklyn  Bensonhurst  4b3a8513f964a520336925e3
# 136  Brooklyn  Bensonhurst  4b721bbcf964a520256f2de3
# 137  Brooklyn  Bensonhurst  4fcc08eebb3d3d2d8021af06
# 138  Brooklyn  Sunset Park  5095a98ae4b0038a605e6f45
#
#                           Name   Latitude  Longitude
# 129  Sofia Restorante Italiano  40.624847 -74.030522
# 135            Europa Pizzeria  40.616583 -73.985708
# 136                  Tommaso's  40.611561 -74.011969
# 137            Tony's Pizzeria  40.619118 -74.008596
# 138                  Cafe Lore  40.648427 -74.010215

# %%
neighbQueens.head()
# Out:
#     Borough     Neighborhood                        ID  \
# 353  Queens          Astoria  5010b169e4b05edd9983ec7d
# 356  Queens  Jackson Heights  4a82d6adf964a5206ff91fe3
# 362  Queens     Howard Beach  5a46a4e72be4257246e053ad
# 371  Queens    East Elmhurst  5480b6d4498e6e352f7a8d3e
# 372  Queens          Maspeth  513d152ee4b0d54ade774b14
#
#                              Name   Latitude  Longitude
# 353  Antika Restaurant & Pizzeria  40.764903 -73.917158
# 356                 Uncle Peter's  40.755786 -73.883810
# 362                        Divino  40.650593 -73.837904
# 371                         Cotto  40.772043 -73.865491
# 372    Forno Pizzeria & Trattoria  40.732795 -73.895626

# %%
candidatesQueens = neighbQueens.groupby('Neighborhood')['ID'].count()
candidatesBrooklyn = neighbBrooklyn.groupby('Neighborhood')['ID'].count()

# %%
print('The are Neighborhoods in Brooklyn with {} italian restaurant(s).'.format(candidatesBrooklyn.min()))
print('The are Neighborhoods in Queens with {} italian restaurant(s).'.format(candidatesQueens.min()))
# Out:
# The are Neighborhoods in Brooklyn with 1 italian restaurant(s).
# The are Neighborhoods in Queens with 1 italian restaurant(s).

# %% [markdown]
# ##  Candidates in Brooklyn:

# %%
type(candidatesQueens)
# Out:
# pandas.core.series.Series

# %%
inBroklyn=candidatesBrooklyn[candidatesBrooklyn <= 1].index.tolist()
for i in inBroklyn:
    print(i)
# Out:
# Bay Ridge
# Boerum Hill
# Coney Island
# Crown Heights
# Ditmas Park
# Downtown
# Erasmus
# Fulton Ferry
# Madison
# Manhattan Beach
# Prospect Heights
# Prospect Lefferts Gardens
# Starrett City
# Sunset Park

# %% [markdown]
# ## Candidates in Queens:

# %%
inQueens=candidatesQueens[candidatesQueens <= 1].index.tolist()
for i in inQueens:
    print(i)
# Out:
# Astoria
# Bellaire
# Blissville
# Briarwood
# Brookville
# East Elmhurst
# Holliswood
# Howard Beach
# Jackson Heights
# Maspeth
# North Corona
# Rockaway Park
# Rosedale
# South Ozone Park
# Utopia
# Whitestone

# %% [markdown]
# ## Conclusion <a name="conclusion"></a>

# %% [markdown]
# Purpose of this project was to find areas of New York with low number of italian restaurants and high density of population.
# The goal was to help the stakeholders narrowing down the search for optimal location for a new Italian restaurant.
# <br><br>
# By calculating the restaurant distribution from Foursquare data and population density we have identified the boroughs and the neighborhoods within them, which could be used as starting points for final exploration by stakeholders.
#
# The final decision requires consideration of a number of additional factors,  specific characteristics of neighborhoods and locations in every recommended area as well the preferences of the stakeholders.
